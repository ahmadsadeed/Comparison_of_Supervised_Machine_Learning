# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Adult data set cleaning:

# %%
import numpy as np
import pandas as pd
# %config InlineBackend.figure_format = 'retina'
pd.options.mode.chained_assignment = None

# %%
adult_data_UCI = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/UCI-adult.csv')

# %%
def binarize(income):
    if (income == '<=50K'): return 0
    else: return 1

# %%
adult_data_UCI['income'] = adult_data_UCI['income'].apply(binarize)
adult_data_UCI.rename(columns={'income':'y'}, inplace=True)

# %%
adult_data_UCI.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'y'],
#       dtype='object')

# %%
# del adult_data_UCI['fnlwgt']
adult_data_UCI.shape
# Out:
# (48842, 15)

# %%
adult_data_UCI = adult_data_UCI.replace('?', np.nan).dropna(axis = 0, how = 'any')
adult_data_UCI.shape
# Out:
# (45222, 15)

# %%
adult_data_UCI = pd.get_dummies(adult_data_UCI)

y = adult_data_UCI.pop('y')
adult_data_UCI['y'] = y
adult_data_UCI = adult_data_UCI.reset_index().drop('index', axis = 1)
# adult_data_UCI.to_csv('/content/drive/MyDrive/Colab Notebooks/data/cleaned/adult.csv')

# %%
adult_data_UCI.shape
# Out:
# (45222, 105)

# %%
print(adult_data_UCI.y.value_counts())
# Out:
# 0    34014
# 1    11208
# Name: y, dtype: int64

# %%
adult_data_UCI.describe()
# Out:
#                 age        fnlwgt  ...  native-country_Yugoslavia             y
# count  45222.000000  4.522200e+04  ...               45222.000000  45222.000000
# mean      38.547941  1.897347e+05  ...                   0.000509      0.247844
# std       13.217870  1.056392e+05  ...                   0.022547      0.431766
# min       17.000000  1.349200e+04  ...                   0.000000      0.000000
# 25%       28.000000  1.173882e+05  ...                   0.000000      0.000000
# 50%       37.000000  1.783160e+05  ...                   0.000000      0.000000
# 75%       47.000000  2.379260e+05  ...                   0.000000      0.000000
# max       90.000000  1.490400e+06  ...                   1.000000      1.000000
#
# [8 rows x 105 columns]

# %% [markdown]
# Letter data set cleaning:

# %%
letter_p1_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/UCI-Letter.csv', header=None)
letter_p2_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/UCI-Letter.csv', header=None)
letter_p1_data.drop([0], inplace=True)
letter_p2_data.drop([0], inplace=True)

# %%
def option1(letter):
    if (letter <= 'M'): return 1
    else: return 0
def option2(letter):
    if (letter == 'O'): return 1
    else: return 0
letter_p1_data[0] = letter_p2_data[0].apply(option1)
letter_p2_data[0] = letter_p2_data[0].apply(option2)

# %%
letter_p1_data.rename(columns={0:'y'}, inplace=True)
letter_p2_data.rename(columns={0:'y'}, inplace=True)
y1 = letter_p1_data.pop('y')
letter_p1_data['y'] = y1
y2 = letter_p2_data.pop('y')
letter_p2_data['y'] = y2

# %%
letter_p1_data.to_csv('/content/drive/MyDrive/Colab Notebooks/data/cleaned/letter_p1.csv')
letter_p2_data.to_csv('/content/drive/MyDrive/Colab Notebooks/data/cleaned/letter_p2.csv')

# %% [markdown]
# Covtype data set cleaning:

# %%
covtype = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/covtype/covtype.data', header = None)
covtype.shape
# Out:
# (581012, 55)

# %%
covtype[54].value_counts()
# Out:
# 2    283301
# 1    211840
# 3     35754
# 7     20510
# 6     17367
# 5      9493
# 4      2747
# Name: 54, dtype: int64

# %%
def binarize_cov(cov_class):
    if (cov_class == 2): return 1
    else: return 0

# %%
# only once
covtype[54] = covtype[54].apply(binarize_cov)

# %%
covtype[54].value_counts()
# Out:
# 0    297711
# 1    283301
# Name: 54, dtype: int64

# %%
# COV TYPE has been converted to a binary problem by treating the largest class as the positive and the rest as negative.

covtype = covtype.reset_index().drop('index', axis = 1)
covtype[54].value_counts()
# Out:
# 0    297711
# 1    283301
# Name: 54, dtype: int64

# %%
covtype.rename(columns={54:'y'}, inplace=True)
covtype['y'].value_counts()
# Out:
# 0    297711
# 1    283301
# Name: y, dtype: int64

# %%
covtype.shape
# Out:
# (581012, 55)

# %%
covtype5 = covtype.sample(frac=0.05, random_state=1)
covtype5.shape
# Out:
# (29051, 55)

# %%
covtype5.y.value_counts()
# Out:
# 0    14892
# 1    14159
# Name: y, dtype: int64

# %%
covtype.to_csv('/content/drive/MyDrive/Colab Notebooks/data/cleaned/covtype.csv')
covtype5.to_csv('/content/drive/MyDrive/Colab Notebooks/data/cleaned/covtype5.csv')
